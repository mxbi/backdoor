# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
plt.figure(figsize=(4, 3))

# control
plt.axhline(y=0.9, xmin=0, xmax=1.0, linestyle='dashed', label="No attack", alpha=0.5)

#badnets
# badnets = [
#     (0, 1),
#     (0.8902, 1.00),
#     (0.8965, 0.986),
    
# #     (0.85, 1.00),
# #     (0.88, 0.956),
# #     (0.89, 0.88),
#     (0.9, 0),
# ]
badnets = [
    (0, 1),
    (0.8685, 0.986),
    (0.8729, 0.9824),
    (0.8818, 0.9794),
    (0.8868, 0.9746),
    (0.8887, 0.9601),
    (0.8921, 0.9425),
    (0.8942, 0.931),

    (0.9, 0),
]
plt.plot(*(list(zip(*badnets))[::-1]), marker='d', label='BadNets', color='green', alpha=0.7)

handcrafted = [
    (0, 1),
    (0.7335, 0.9734),
    (0.7802, 0.9533),
#     (0.7733, 0.9385),
    (0.8178, 0.9195),
    (0.8305, 0.7334),
    (0.8448, 0.4271),
    (0.8725, 0.1891),
    (0.9, 0),
]

plt.plot(*(list(zip(*handcrafted))[::-1]), marker='X', c='red', label='Handcrafted', alpha=0.7)

plt.xlabel('Backdoor success rate')
plt.ylabel("Alice's Accuracy")

ax = plt.gcf().get_axes()[0]

plt.xlim(0, 1.02)
plt.ylim(0.7, 0.91)

vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

vals = ax.get_xticks()
ax.set_xticklabels(['{:,.0%}'.format(x) for x in vals])

plt.legend()

import matplotlib.patches as patches
ax.add_patch(patches.Rectangle((1, 0), 1, 1, color='black', alpha=0.1, linewidth=0))
# ax.add_patch(patches.Rectangle((0, 0.9), 1, 1, color='black', alpha=0.1, linewidth=0))

plt.savefig('../output/tm1_comparison.pdf', bbox_inches='tight')
# Out:
# <ipython-input-110-becea8d5d0d9>:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])
# <ipython-input-110-becea8d5d0d9>:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
(list(zip(*badnets))[::-1])
# Out:
# [(1, 0.89, 0), (0, 0.99, 0.9)]
